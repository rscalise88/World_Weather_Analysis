# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time


# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fae06789b88cd77d413e0abc50acf1e5

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Weather": city_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arlit
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | skibbereen
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | mandera
# Processing Record 9 of Set 1 | tadine
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | jemnice
# Processing Record 12 of Set 1 | ghanzi
# Processing Record 13 of Set 1 | dawei
# Processing Record 14 of Set 1 | ochakiv
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | marawi
# Processing Record 17 of Set 1 | khorramshahr
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | ixtapa
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | vrangel
# Processing Record 22 of Set 1 | peruibe
# Processing Record 23 of Set 1 | taoudenni
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | havre-saint-pierre
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | salalah
# Processing Record 28 of Set 1 | chumphon
# Processing Record 29 of Set 1 | college
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 1 | oranjemund
# Processing Record 35 of Set 1 | honningsvag
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | djibo
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | novikovo
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | faya
# Processing Record 44 of Set 1 | joshimath
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | gogrial
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | tiksi
# Processing Record 1 of Set 2 | lazaro cardenas
# Processing Record 2 of Set 2 | bay roberts
# Processing Record 3 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | kysyl-syr
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | cockburn town
# Processing Record 8 of Set 2 | gidole
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | airai
# Processing Record 14 of Set 2 | toppenish
# Processing Record 15 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | nkhotakota
# Processing Record 18 of Set 2 | general roca
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | norman wells
# Processing Record 23 of Set 2 | terrace
# Processing Record 24 of Set 2 | riyadh
# Processing Record 25 of Set 2 | ahipara
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | pasinler
# Processing Record 29 of Set 2 | kargasok
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | leeton
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | east london
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | carballo
# Processing Record 38 of Set 2 | port blair
# Processing Record 39 of Set 2 | yumen
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | waddan
# Processing Record 42 of Set 2 | te anau
# Processing Record 43 of Set 2 | langxiang
# Processing Record 44 of Set 2 | gravdal
# Processing Record 45 of Set 2 | pisco
# Processing Record 46 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 2 | andrews
# Processing Record 48 of Set 2 | adre
# Processing Record 49 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 2 | igbo ora
# Processing Record 1 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 3 | khatanga
# Processing Record 3 of Set 3 | vestmannaeyjar
# Processing Record 4 of Set 3 | reconquista
# Processing Record 5 of Set 3 | florenville
# Processing Record 6 of Set 3 | praia da vitoria
# Processing Record 7 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 3 | prince albert
# Processing Record 9 of Set 3 | ust-tsilma
# Processing Record 10 of Set 3 | mumford
# Processing Record 11 of Set 3 | praia
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | ugoofaaru
# Processing Record 14 of Set 3 | clyde river
# Processing Record 15 of Set 3 | coihaique
# Processing Record 16 of Set 3 | madona
# Processing Record 17 of Set 3 | rocky mountain house
# Processing Record 18 of Set 3 | bathsheba
# Processing Record 19 of Set 3 | kirakira
# Processing Record 20 of Set 3 | sambava
# Processing Record 21 of Set 3 | aneho
# Processing Record 22 of Set 3 | mayo
# Processing Record 23 of Set 3 | hami
# Processing Record 24 of Set 3 | sinnamary
# Processing Record 25 of Set 3 | sartell
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | sembakung
# Processing Record 29 of Set 3 | kenora
# Processing Record 30 of Set 3 | camocim
# Processing Record 31 of Set 3 | tarnogskiy gorodok
# Processing Record 32 of Set 3 | ntcheu
# Processing Record 33 of Set 3 | pahrump
# Processing Record 34 of Set 3 | starokostyantyniv
# Processing Record 35 of Set 3 | tiarei
# Processing Record 36 of Set 3 | luena
# Processing Record 37 of Set 3 | hobart
# Processing Record 38 of Set 3 | russell
# Processing Record 39 of Set 3 | colac
# Processing Record 40 of Set 3 | newport
# Processing Record 41 of Set 3 | mochumi
# Processing Record 42 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 3 | souillac
# Processing Record 44 of Set 3 | zhigansk
# Processing Record 45 of Set 3 | port alfred
# Processing Record 46 of Set 3 | broome
# Processing Record 47 of Set 3 | tuatapere
# Processing Record 48 of Set 3 | ostrovnoy
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 4 | corinto
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | gainesville
# Processing Record 4 of Set 4 | plettenberg bay
# Processing Record 5 of Set 4 | christchurch
# Processing Record 6 of Set 4 | blythe
# Processing Record 7 of Set 4 | galesong
# Processing Record 8 of Set 4 | reichenau
# Processing Record 9 of Set 4 | shache
# Processing Record 10 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | moose factory
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | solnechnyy
# Processing Record 15 of Set 4 | the valley
# Processing Record 16 of Set 4 | grand forks
# Processing Record 17 of Set 4 | bam
# Processing Record 18 of Set 4 | uribia
# Processing Record 19 of Set 4 | mulchen
# Processing Record 20 of Set 4 | kahului
# Processing Record 21 of Set 4 | praya
# Processing Record 22 of Set 4 | bambous virieux
# Processing Record 23 of Set 4 | kaitangata
# Processing Record 24 of Set 4 | acapulco
# Processing Record 25 of Set 4 | arman
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | paka
# Processing Record 28 of Set 4 | valle nacional
# Processing Record 29 of Set 4 | mount gambier
# Processing Record 30 of Set 4 | niquero
# Processing Record 31 of Set 4 | beruni
# City not found. Skipping...
# Processing Record 32 of Set 4 | kruisfontein
# Processing Record 33 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | yerbogachen
# Processing Record 35 of Set 4 | dourbali
# Processing Record 36 of Set 4 | luderitz
# Processing Record 37 of Set 4 | neyyattinkara
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | hoquiam
# Processing Record 40 of Set 4 | boyolangu
# Processing Record 41 of Set 4 | lianzhou
# Processing Record 42 of Set 4 | seoul
# Processing Record 43 of Set 4 | ilulissat
# Processing Record 44 of Set 4 | thaba nchu
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | guye
# Processing Record 47 of Set 4 | jurado
# Processing Record 48 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 49 of Set 4 | hobyo
# Processing Record 50 of Set 4 | heyang
# Processing Record 1 of Set 5 | nakhon ratchasima
# Processing Record 2 of Set 5 | panuco
# Processing Record 3 of Set 5 | atuona
# Processing Record 4 of Set 5 | mugla
# Processing Record 5 of Set 5 | yulara
# Processing Record 6 of Set 5 | amapa
# Processing Record 7 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 5 | syamzha
# Processing Record 9 of Set 5 | qaanaaq
# Processing Record 10 of Set 5 | duz
# City not found. Skipping...
# Processing Record 11 of Set 5 | sao joao da barra
# Processing Record 12 of Set 5 | coos bay
# Processing Record 13 of Set 5 | westport
# Processing Record 14 of Set 5 | goderich
# Processing Record 15 of Set 5 | salym
# Processing Record 16 of Set 5 | banepa
# Processing Record 17 of Set 5 | kavieng
# Processing Record 18 of Set 5 | provideniya
# Processing Record 19 of Set 5 | la rioja
# Processing Record 20 of Set 5 | lasa
# Processing Record 21 of Set 5 | hornepayne
# Processing Record 22 of Set 5 | sawakin
# Processing Record 23 of Set 5 | lodwar
# Processing Record 24 of Set 5 | cayenne
# Processing Record 25 of Set 5 | saint-francois
# Processing Record 26 of Set 5 | bandarbeyla
# Processing Record 27 of Set 5 | cyangugu
# Processing Record 28 of Set 5 | perevolotskiy
# Processing Record 29 of Set 5 | buala
# Processing Record 30 of Set 5 | namatanai
# Processing Record 31 of Set 5 | tanabe
# Processing Record 32 of Set 5 | otradnoye
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 35 of Set 5 | argudan
# Processing Record 36 of Set 5 | san cristobal
# Processing Record 37 of Set 5 | poronaysk
# Processing Record 38 of Set 5 | almaznyy
# Processing Record 39 of Set 5 | coquimbo
# Processing Record 40 of Set 5 | korocha
# Processing Record 41 of Set 5 | northam
# Processing Record 42 of Set 5 | fairbanks
# Processing Record 43 of Set 5 | ca mau
# Processing Record 44 of Set 5 | marsh harbour
# Processing Record 45 of Set 5 | otradinskiy
# City not found. Skipping...
# Processing Record 46 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 5 | broken hill
# Processing Record 48 of Set 5 | vanimo
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 1 of Set 6 | korla
# Processing Record 2 of Set 6 | hofn
# Processing Record 3 of Set 6 | port moresby
# Processing Record 4 of Set 6 | ballina
# Processing Record 5 of Set 6 | itarema
# Processing Record 6 of Set 6 | kalmunai
# Processing Record 7 of Set 6 | malanville
# Processing Record 8 of Set 6 | hambantota
# Processing Record 9 of Set 6 | bengkulu
# Processing Record 10 of Set 6 | cherskiy
# Processing Record 11 of Set 6 | ponta do sol
# Processing Record 12 of Set 6 | chuy
# Processing Record 13 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 6 | caravelas
# Processing Record 15 of Set 6 | la ronge
# Processing Record 16 of Set 6 | malanje
# Processing Record 17 of Set 6 | batagay-alyta
# Processing Record 18 of Set 6 | burnie
# Processing Record 19 of Set 6 | sovetskoye
# Processing Record 20 of Set 6 | isangel
# Processing Record 21 of Set 6 | sidi ali
# Processing Record 22 of Set 6 | esperance
# Processing Record 23 of Set 6 | santa cruz
# Processing Record 24 of Set 6 | muros
# Processing Record 25 of Set 6 | guerrero negro
# Processing Record 26 of Set 6 | aklavik
# Processing Record 27 of Set 6 | vallenar
# Processing Record 28 of Set 6 | kaifeng
# Processing Record 29 of Set 6 | ciudad bolivar
# Processing Record 30 of Set 6 | tukrah
# Processing Record 31 of Set 6 | porangatu
# Processing Record 32 of Set 6 | aswan
# Processing Record 33 of Set 6 | izumo
# Processing Record 34 of Set 6 | havelock
# Processing Record 35 of Set 6 | leningradskiy
# Processing Record 36 of Set 6 | olafsvik
# Processing Record 37 of Set 6 | port hardy
# Processing Record 38 of Set 6 | senno
# Processing Record 39 of Set 6 | baruun-urt
# Processing Record 40 of Set 6 | san policarpo
# Processing Record 41 of Set 6 | conde
# Processing Record 42 of Set 6 | kyra
# Processing Record 43 of Set 6 | kiunga
# Processing Record 44 of Set 6 | batticaloa
# Processing Record 45 of Set 6 | shenjiamen
# Processing Record 46 of Set 6 | benghazi
# Processing Record 47 of Set 6 | makung
# City not found. Skipping...
# Processing Record 48 of Set 6 | krasnokamensk
# Processing Record 49 of Set 6 | slanic-moldova
# Processing Record 50 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 7 | thompson
# Processing Record 2 of Set 7 | kirundo
# Processing Record 3 of Set 7 | saint-augustin
# Processing Record 4 of Set 7 | santa cruz de tenerife
# Processing Record 5 of Set 7 | makakilo city
# Processing Record 6 of Set 7 | margate
# Processing Record 7 of Set 7 | baherden
# Processing Record 8 of Set 7 | acarau
# Processing Record 9 of Set 7 | lata
# Processing Record 10 of Set 7 | grootfontein
# Processing Record 11 of Set 7 | trat
# Processing Record 12 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 13 of Set 7 | adrar
# Processing Record 14 of Set 7 | erzin
# Processing Record 15 of Set 7 | maniitsoq
# Processing Record 16 of Set 7 | belmonte
# Processing Record 17 of Set 7 | krasnoselkup
# Processing Record 18 of Set 7 | excelsior springs
# Processing Record 19 of Set 7 | lhokseumawe
# Processing Record 20 of Set 7 | anloga
# Processing Record 21 of Set 7 | turukhansk
# Processing Record 22 of Set 7 | udachnyy
# Processing Record 23 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 7 | lagunas
# Processing Record 25 of Set 7 | opuwo
# Processing Record 26 of Set 7 | kieta
# Processing Record 27 of Set 7 | copiapo
# Processing Record 28 of Set 7 | alofi
# Processing Record 29 of Set 7 | ketchikan
# Processing Record 30 of Set 7 | avera
# Processing Record 31 of Set 7 | cheremukhovo
# Processing Record 32 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 33 of Set 7 | storforshei
# Processing Record 34 of Set 7 | saint george
# Processing Record 35 of Set 7 | san-pedro
# Processing Record 36 of Set 7 | nuristan
# Processing Record 37 of Set 7 | san quintin
# Processing Record 38 of Set 7 | hashtgerd
# Processing Record 39 of Set 7 | noumea
# Processing Record 40 of Set 7 | alihe
# Processing Record 41 of Set 7 | muzhi
# Processing Record 42 of Set 7 | cabo san lucas
# Processing Record 43 of Set 7 | dukat
# Processing Record 44 of Set 7 | lyubinskiy
# Processing Record 45 of Set 7 | maldonado
# Processing Record 46 of Set 7 | port lincoln
# Processing Record 47 of Set 7 | maracacume
# Processing Record 48 of Set 7 | sugbongcogon
# Processing Record 49 of Set 7 | los llanos de aridane
# Processing Record 50 of Set 7 | san jose
# Processing Record 1 of Set 8 | hervey bay
# Processing Record 2 of Set 8 | pyshchug
# Processing Record 3 of Set 8 | acari
# Processing Record 4 of Set 8 | novyy urengoy
# Processing Record 5 of Set 8 | rocha
# Processing Record 6 of Set 8 | yatou
# Processing Record 7 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 8 of Set 8 | liverpool
# Processing Record 9 of Set 8 | igarka
# Processing Record 10 of Set 8 | lagoa
# Processing Record 11 of Set 8 | saldanha
# Processing Record 12 of Set 8 | kamaishi
# Processing Record 13 of Set 8 | muscat
# Processing Record 14 of Set 8 | bluefields
# Processing Record 15 of Set 8 | kinablangan
# Processing Record 16 of Set 8 | bubaque
# Processing Record 17 of Set 8 | ribeira grande
# Processing Record 18 of Set 8 | ekibastuz
# Processing Record 19 of Set 8 | apache junction
# Processing Record 20 of Set 8 | bereda
# Processing Record 21 of Set 8 | talnakh
# Processing Record 22 of Set 8 | sinegorye
# Processing Record 23 of Set 8 | chingirlau
# Processing Record 24 of Set 8 | along
# Processing Record 25 of Set 8 | antalaha
# Processing Record 26 of Set 8 | bima
# Processing Record 27 of Set 8 | escanaba
# Processing Record 28 of Set 8 | vaitape
# Processing Record 29 of Set 8 | martil
# Processing Record 30 of Set 8 | pierre
# Processing Record 31 of Set 8 | irmo
# Processing Record 32 of Set 8 | jiuquan
# Processing Record 33 of Set 8 | san luis
# Processing Record 34 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 8 | klaksvik
# Processing Record 36 of Set 8 | bonthe
# Processing Record 37 of Set 8 | iglesias
# Processing Record 38 of Set 8 | karasburg
# Processing Record 39 of Set 8 | lucapa
# Processing Record 40 of Set 8 | xam nua
# Processing Record 41 of Set 8 | borogontsy
# Processing Record 42 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 8 | soyo
# Processing Record 44 of Set 8 | uyskoye
# Processing Record 45 of Set 8 | campbell river
# Processing Record 46 of Set 8 | san patricio
# Processing Record 47 of Set 8 | masalli
# Processing Record 48 of Set 8 | stargard szczecinski
# Processing Record 49 of Set 8 | mbandaka
# Processing Record 50 of Set 8 | havoysund
# Processing Record 1 of Set 9 | erenhot
# Processing Record 2 of Set 9 | lorengau
# Processing Record 3 of Set 9 | smithers
# Processing Record 4 of Set 9 | west bay
# Processing Record 5 of Set 9 | biankouma
# Processing Record 6 of Set 9 | chapais
# Processing Record 7 of Set 9 | sabang
# Processing Record 8 of Set 9 | hamilton
# Processing Record 9 of Set 9 | talara
# Processing Record 10 of Set 9 | pittsburg
# Processing Record 11 of Set 9 | buluang
# Processing Record 12 of Set 9 | seymchan
# Processing Record 13 of Set 9 | kyren
# Processing Record 14 of Set 9 | altay
# Processing Record 15 of Set 9 | severnyy
# Processing Record 16 of Set 9 | sorland
# Processing Record 17 of Set 9 | vilyuysk
# Processing Record 18 of Set 9 | karratha
# Processing Record 19 of Set 9 | kissidougou
# Processing Record 20 of Set 9 | shar
# Processing Record 21 of Set 9 | antipino
# Processing Record 22 of Set 9 | rio branco do sul
# Processing Record 23 of Set 9 | mackenzie
# Processing Record 24 of Set 9 | fortuna
# Processing Record 25 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 26 of Set 9 | aldan
# Processing Record 27 of Set 9 | englewood
# Processing Record 28 of Set 9 | toul
# Processing Record 29 of Set 9 | biskupiec
# Processing Record 30 of Set 9 | ust-kut
# Processing Record 31 of Set 9 | road town
# Processing Record 32 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 9 | geraldton
# Processing Record 34 of Set 9 | atar
# Processing Record 35 of Set 9 | tual
# Processing Record 36 of Set 9 | torbay
# Processing Record 37 of Set 9 | mehamn
# Processing Record 38 of Set 9 | isa khel
# Processing Record 39 of Set 9 | humaita
# Processing Record 40 of Set 9 | daitari
# Processing Record 41 of Set 9 | skarnes
# Processing Record 42 of Set 9 | puerto baquerizo moreno
# Processing Record 43 of Set 9 | komsomolskiy
# Processing Record 44 of Set 9 | grand gaube
# Processing Record 45 of Set 9 | samarai
# Processing Record 46 of Set 9 | balkanabat
# Processing Record 47 of Set 9 | taltal
# Processing Record 48 of Set 9 | vegreville
# Processing Record 49 of Set 9 | artyom
# Processing Record 50 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 1 of Set 10 | kitimat
# Processing Record 2 of Set 10 | clarence town
# Processing Record 3 of Set 10 | shellbrook
# Processing Record 4 of Set 10 | srednekolymsk
# Processing Record 5 of Set 10 | taksimo
# Processing Record 6 of Set 10 | natal
# Processing Record 7 of Set 10 | tuburan
# Processing Record 8 of Set 10 | abong mbang
# Processing Record 9 of Set 10 | matamoros
# Processing Record 10 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 10 | klyuchi
# Processing Record 12 of Set 10 | tacuarembo
# Processing Record 13 of Set 10 | waverly
# Processing Record 14 of Set 10 | husavik
# Processing Record 15 of Set 10 | wanning
# Processing Record 16 of Set 10 | codrington
# Processing Record 17 of Set 10 | bambanglipuro
# Processing Record 18 of Set 10 | pipri
# Processing Record 19 of Set 10 | bamenda
# Processing Record 20 of Set 10 | narsaq
# Processing Record 21 of Set 10 | sechura
# Processing Record 22 of Set 10 | kropotkin
# Processing Record 23 of Set 10 | le port
# Processing Record 24 of Set 10 | lexington
# Processing Record 25 of Set 10 | hede
# Processing Record 26 of Set 10 | karasjok
# Processing Record 27 of Set 10 | marang
# Processing Record 28 of Set 10 | nisia floresta
# Processing Record 29 of Set 10 | cochrane
# Processing Record 30 of Set 10 | mackay
# Processing Record 31 of Set 10 | santa maria da vitoria
# Processing Record 32 of Set 10 | cap malheureux
# Processing Record 33 of Set 10 | moron
# Processing Record 34 of Set 10 | penzance
# Processing Record 35 of Set 10 | hirara
# Processing Record 36 of Set 10 | yarmouth
# Processing Record 37 of Set 10 | juneau
# Processing Record 38 of Set 10 | mozarlandia
# Processing Record 39 of Set 10 | marsa matruh
# Processing Record 40 of Set 10 | bilma
# Processing Record 41 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 10 | mount isa
# Processing Record 43 of Set 10 | boden
# Processing Record 44 of Set 10 | ouesso
# Processing Record 45 of Set 10 | zhangye
# Processing Record 46 of Set 10 | ngozi
# Processing Record 47 of Set 10 | kavaratti
# Processing Record 48 of Set 10 | kutum
# Processing Record 49 of Set 10 | lagos
# Processing Record 50 of Set 10 | berlevag
# Processing Record 1 of Set 11 | lumberton
# Processing Record 2 of Set 11 | helong
# Processing Record 3 of Set 11 | konza
# Processing Record 4 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 11 | chauk
# Processing Record 6 of Set 11 | laguna de perlas
# Processing Record 7 of Set 11 | rovaniemi
# Processing Record 8 of Set 11 | jaramana
# City not found. Skipping...
# Processing Record 9 of Set 11 | teseney
# Processing Record 10 of Set 11 | scalea
# Processing Record 11 of Set 11 | djambala
# Processing Record 12 of Set 11 | bara
# Processing Record 13 of Set 11 | asau
# Processing Record 14 of Set 11 | najran
# Processing Record 15 of Set 11 | kamenka
# Processing Record 16 of Set 11 | igbon
# Processing Record 17 of Set 11 | rzeszow
# Processing Record 18 of Set 11 | evensk
# Processing Record 19 of Set 11 | depok
# Processing Record 20 of Set 11 | kudat
# Processing Record 21 of Set 11 | aksu
# Processing Record 22 of Set 11 | santa maria
# Processing Record 23 of Set 11 | svetlyy
# Processing Record 24 of Set 11 | kawambwa
# Processing Record 25 of Set 11 | budogoshch
# Processing Record 26 of Set 11 | saint-leu
# Processing Record 27 of Set 11 | todos santos
# Processing Record 28 of Set 11 | ler
# Processing Record 29 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 11 | nouadhibou
# Processing Record 31 of Set 11 | ushtobe
# Processing Record 32 of Set 11 | virginia beach
# Processing Record 33 of Set 11 | saint-pierre
# Processing Record 34 of Set 11 | faanui
# Processing Record 35 of Set 11 | porto santo
# Processing Record 36 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 11 | moerai
# Processing Record 38 of Set 11 | ambon
# Processing Record 39 of Set 11 | calama
# Processing Record 40 of Set 11 | golden
# Processing Record 41 of Set 11 | dinghai
# Processing Record 42 of Set 11 | changji
# Processing Record 43 of Set 11 | honggang
# Processing Record 44 of Set 11 | perbaungan
# Processing Record 45 of Set 11 | meulaboh
# Processing Record 46 of Set 11 | auki
# Processing Record 47 of Set 11 | cap-aux-meules
# Processing Record 48 of Set 11 | quatre cocos
# Processing Record 49 of Set 11 | salta
# Processing Record 50 of Set 11 | laguna
# Processing Record 1 of Set 12 | inirida
# Processing Record 2 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 12 | kentau
# Processing Record 5 of Set 12 | wagar
# Processing Record 6 of Set 12 | lapua
# Processing Record 7 of Set 12 | shieli
# Processing Record 8 of Set 12 | vila franca do campo
# Processing Record 9 of Set 12 | tazovskiy
# Processing Record 10 of Set 12 | vila velha
# Processing Record 11 of Set 12 | chake chake
# Processing Record 12 of Set 12 | griffith
# Processing Record 13 of Set 12 | kursk
# Processing Record 14 of Set 12 | nishihara
# Processing Record 15 of Set 12 | honiara
# Processing Record 16 of Set 12 | tourlaville
# Processing Record 17 of Set 12 | uchiza
# Processing Record 18 of Set 12 | tura
# Processing Record 19 of Set 12 | qandala
# Processing Record 20 of Set 12 | sangar
# Processing Record 21 of Set 12 | wukari
# Processing Record 22 of Set 12 | newcastle
# Processing Record 23 of Set 12 | hovd
# Processing Record 24 of Set 12 | rach gia
# Processing Record 25 of Set 12 | prado
# Processing Record 26 of Set 12 | comodoro rivadavia
# Processing Record 27 of Set 12 | daru
# Processing Record 28 of Set 12 | siocon
# Processing Record 29 of Set 12 | bethel
# Processing Record 30 of Set 12 | rio grande
# Processing Record 31 of Set 12 | freeport
# Processing Record 32 of Set 12 | pontianak
# Processing Record 33 of Set 12 | thoen
# Processing Record 34 of Set 12 | linjiang
# Processing Record 35 of Set 12 | grindavik
# Processing Record 36 of Set 12 | wisconsin rapids
# Processing Record 37 of Set 12 | salinopolis
# Processing Record 38 of Set 12 | sitka
# Processing Record 39 of Set 12 | muisne
# Processing Record 40 of Set 12 | port hedland
# Processing Record 41 of Set 12 | woodward
# Processing Record 42 of Set 12 | bozeman
# Processing Record 43 of Set 12 | lompoc
# Processing Record 44 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 12 | atasu
# Processing Record 46 of Set 12 | asekeyevo
# Processing Record 47 of Set 12 | pangnirtung
# Processing Record 48 of Set 12 | kashmor
# Processing Record 49 of Set 12 | buraydah
# Processing Record 50 of Set 12 | baghdad
# Processing Record 1 of Set 13 | paita
# Processing Record 2 of Set 13 | kjollefjord
# Processing Record 3 of Set 13 | itigi
# Processing Record 4 of Set 13 | fatsa
# Processing Record 5 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 6 of Set 13 | sanmenxia
# Processing Record 7 of Set 13 | wattegama
# Processing Record 8 of Set 13 | parintins
# Processing Record 9 of Set 13 | sola
# Processing Record 10 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 13 | kirovskiy
# Processing Record 12 of Set 13 | fuerte olimpo
# Processing Record 13 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 13 | vavozh
# Processing Record 15 of Set 13 | akranes
# Processing Record 16 of Set 13 | svetlogorsk
# Processing Record 17 of Set 13 | merrill
# Processing Record 18 of Set 13 | nanortalik
# Processing Record 19 of Set 13 | sawtell
# Processing Record 20 of Set 13 | aden
# Processing Record 21 of Set 13 | winfield
# Processing Record 22 of Set 13 | strezhevoy
# Processing Record 23 of Set 13 | falun
# Processing Record 24 of Set 13 | kupang
# Processing Record 25 of Set 13 | floriano
# Processing Record 26 of Set 13 | la palma
# Processing Record 27 of Set 13 | gat
# Processing Record 28 of Set 13 | morondava
# Processing Record 29 of Set 13 | mecca
# Processing Record 30 of Set 13 | tommot
# Processing Record 31 of Set 13 | tadpatri
# Processing Record 32 of Set 13 | idritsa
# Processing Record 33 of Set 13 | haines junction
# Processing Record 34 of Set 13 | kudahuvadhoo
# Processing Record 35 of Set 13 | beloha
# Processing Record 36 of Set 13 | hushitai
# Processing Record 37 of Set 13 | sorong
# Processing Record 38 of Set 13 | shelburne
# Processing Record 39 of Set 13 | gambela
# Processing Record 40 of Set 13 | tateyama
# Processing Record 41 of Set 13 | new glasgow
# Processing Record 42 of Set 13 | maple creek
# Processing Record 43 of Set 13 | bulgan
# Processing Record 44 of Set 13 | meadow lake
# Processing Record 45 of Set 13 | henties bay
# Processing Record 46 of Set 13 | kununurra
# Processing Record 47 of Set 13 | krasnoarmeysk
# Processing Record 48 of Set 13 | phumi samraong
# City not found. Skipping...
# Processing Record 49 of Set 13 | dunedin
# Processing Record 50 of Set 13 | veraval
# Processing Record 1 of Set 14 | rundu
# Processing Record 2 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 14 | hawalli
# Processing Record 4 of Set 14 | nanyang
# Processing Record 5 of Set 14 | ambanja
# Processing Record 6 of Set 14 | harbour breton
# Processing Record 7 of Set 14 | mocuba
# Processing Record 8 of Set 14 | vao
# Processing Record 9 of Set 14 | jumla
# Processing Record 10 of Set 14 | asfi
# Processing Record 11 of Set 14 | semey
# Processing Record 12 of Set 14 | diego de almagro
# Processing Record 13 of Set 14 | qala
# Processing Record 14 of Set 14 | portland
# Processing Record 15 of Set 14 | myrtle beach
# Processing Record 16 of Set 14 | esna
# Processing Record 17 of Set 14 | balad
# Processing Record 18 of Set 14 | seddon
# Processing Record 19 of Set 14 | cibitoke
# Processing Record 20 of Set 14 | teya
# Processing Record 21 of Set 14 | tiznit
# Processing Record 22 of Set 14 | kolyvan
# Processing Record 23 of Set 14 | catuday
# Processing Record 24 of Set 14 | dingle
# Processing Record 25 of Set 14 | prince rupert
# Processing Record 26 of Set 14 | saint-joseph
# Processing Record 27 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 28 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 14 | van
# Processing Record 30 of Set 14 | ituiutaba
# Processing Record 31 of Set 14 | galle
# Processing Record 32 of Set 14 | carmen
# Processing Record 33 of Set 14 | fuyu
# Processing Record 34 of Set 14 | inverness
# Processing Record 35 of Set 14 | duzce
# Processing Record 36 of Set 14 | manzil jamil
# City not found. Skipping...
# Processing Record 37 of Set 14 | sosnovo-ozerskoye
# Processing Record 38 of Set 14 | hudson bay
# Processing Record 39 of Set 14 | balkhash
# Processing Record 40 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 14 | kofarnihon
# City not found. Skipping...
# Processing Record 42 of Set 14 | manzhouli
# Processing Record 43 of Set 14 | necochea
# Processing Record 44 of Set 14 | abonnema
# Processing Record 45 of Set 14 | nokaneng
# Processing Record 46 of Set 14 | yar-sale
# Processing Record 47 of Set 14 | patti
# Processing Record 48 of Set 14 | ewa beach
# Processing Record 49 of Set 14 | aksarka
# Processing Record 50 of Set 14 | steinbach
# Processing Record 1 of Set 15 | naze
# Processing Record 2 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 3 of Set 15 | valle de allende
# Processing Record 4 of Set 15 | impfondo
# Processing Record 5 of Set 15 | tartki
# City not found. Skipping...
# Processing Record 6 of Set 15 | sussex
# Processing Record 7 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 8 of Set 15 | bar harbor
# Processing Record 9 of Set 15 | loreto
# Processing Record 10 of Set 15 | plesetsk
# Processing Record 11 of Set 15 | verkh-usugli
# Processing Record 12 of Set 15 | varhaug
# Processing Record 13 of Set 15 | mlonggo
# Processing Record 14 of Set 15 | sao miguel do araguaia
# Processing Record 15 of Set 15 | suao
# City not found. Skipping...
# Processing Record 16 of Set 15 | kabompo
# Processing Record 17 of Set 15 | chesma
# Processing Record 18 of Set 15 | wageningen
# Processing Record 19 of Set 15 | san ramon de la nueva oran
# Processing Record 20 of Set 15 | vardo
# Processing Record 21 of Set 15 | chicama
# Processing Record 22 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 23 of Set 15 | champerico
# Processing Record 24 of Set 15 | kattivakkam
# Processing Record 25 of Set 15 | pacific grove
# Processing Record 26 of Set 15 | mahibadhoo
# Processing Record 27 of Set 15 | shingu
# Processing Record 28 of Set 15 | baykit
# Processing Record 29 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 15 | kuytun
# Processing Record 31 of Set 15 | shizunai
# Processing Record 32 of Set 15 | millau
# Processing Record 33 of Set 15 | cabedelo
# Processing Record 34 of Set 15 | flinders
# Processing Record 35 of Set 15 | port macquarie
# Processing Record 36 of Set 15 | gao
# Processing Record 37 of Set 15 | terra santa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng   Current Weather  Max Temp  Humidity  \
# 0       Arlit  18.7369    7.3853  scattered clouds     97.61        26
# 1     Mataura -46.1927  168.8643     broken clouds     39.47        98
# 2       Kapaa  22.0752 -159.3190        light rain     80.58        83
# 3     Ushuaia -54.8000  -68.3000         clear sky     46.06        61
# 4  Skibbereen  51.5500   -9.2667   overcast clouds     62.40        66
# 5      Albany  42.6001  -73.9662        light rain     76.39        66
# 6     Mandera   3.9366   41.8670   overcast clouds     82.85        48
# 7      Tadine -21.5500  167.8833     broken clouds     66.78        56
# 8   Saskylakh  71.9167  114.0833         clear sky     65.25        49
# 9     Jemnice  49.0190   15.5699   overcast clouds     61.95        89
#
#    Cloudiness  Wind Speed Country                 Date
# 0          28       10.11      NE  2021-08-01 18:58:41
# 1          64        3.74      NZ  2021-08-01 18:54:59
# 2          93        1.01      US  2021-08-01 18:58:14
# 3           0        5.75      AR  2021-08-01 18:55:05
# 4          99       11.30      IE  2021-08-01 19:04:01
# 5          55        8.10      US  2021-08-01 18:55:23
# 6          95       21.90      KE  2021-08-01 19:02:17
# 7          61       12.10      NC  2021-08-01 19:04:02
# 8           0        5.37      RU  2021-08-01 19:02:53
# 9         100        8.90      CZ  2021-08-01 19:04:02

# %%
# Create the output file (CSV).
output_data_file = "weather_database/weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
